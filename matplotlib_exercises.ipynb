# %%
import matplotlib.pyplot as plt
from math import *

# %% [markdown]
# ### 1. Use matplotlib to plot the following equation:
#
# y
# =
# x^
# 2
# −
# x
# +
# 2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x1 = range(-10, 10)
y1 = [n**2 - n + 2 for n in x]

# %%
plt.plot(x1, y1, c = 'mediumblue')
plt.scatter(x1, y1, c = 'black')
plt.text(-.75, 8, '(0, 0)', fontsize = 10, color = 'firebrick')
plt.title('y = x^2 - x + 2')
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(x = 0, c = 'black')

# %% [markdown]
# ### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y
# =
# √
# x
#
# y
# =
# x
# 3
#
# y
# =
# 2
# x
# You can use functions from the math module to help implement some of the equations above.

# %%
x2 = range(0, 10)
y2 = [sqrt(n) for n in x2]
plt.plot(x2, y2)
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.title('y = sqrt(x)')
plt.axhline(y = 0, c = 'black')
plt.axvline(x = 0, c = 'black')

# %%
x3 = range(-10, 10)
y3 = [n ** 3 for n in x3]

plt.plot(x3, y3)
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.title('y = x^3')
plt.axhline(y = 0, c = 'black')
plt.axvline(x = 0, c = 'black')

# %%
x4 = range(-10, 10)
y4 = [2 ** n for n in x4]

plt.plot(x4, y4)
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.title('y = 2^x')
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')

# %%
n_rows = 2
n_cols = 2

plt.subplot(n_rows, n_cols, 1)
plt.plot(x1, y1)
plt.title('y = x^2 - x + 2')
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')

plt.subplot(n_rows, n_cols, 2)
plt.plot(x2, y2)
plt.title('y = sqrt(x)')
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')

plt.subplot(n_rows, n_cols, 3)
plt.plot(x3, y3)
plt.title('y = x^3')
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')

plt.subplot(n_rows, n_cols, 4)
plt.plot(x4, y4)
plt.title('y = 2^x')
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')

plt.tight_layout()
plt.show()

# %%
x1 = range(-10, 11)
x2 = range(0, 11)
y1 = [n ** 2 - n + 2 for n in x1]
y2 = [sqrt(n) for n in x2]
y3 = [n ** 3 for n in x1]
y4 = [2 ** n for n in x1]

plt.plot(x1, y1, c = 'red', label = '$x^2 - x + 2$')
plt.plot(x2, y2, c = 'blue', label = '$sqrt(x)$')
plt.plot(x1, y3, c = 'yellow', label = '$x^3$')
plt.plot(x1, y4, 'purple', label = '$2^x$')
plt.ylim(-50, 50)
plt.grid(c = 'slategray', linestyle = '-', linewidth = .5)
plt.axhline(y = 0, c = 'black')
plt.axvline(c = 'black')
plt.legend()

plt.show()
